# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#                                              0.0/10.6 MB 991.0 kB/s eta 0:00:11
#                                               0.1/10.6 MB 1.4 MB/s eta 0:00:08
#                                               0.2/10.6 MB 2.1 MB/s eta 0:00:06
#      -                                        0.4/10.6 MB 2.1 MB/s eta 0:00:05
#      --                                       0.6/10.6 MB 2.8 MB/s eta 0:00:04
#      ---                                      0.9/10.6 MB 3.3 MB/s eta 0:00:03
#      -----                                    1.4/10.6 MB 4.5 MB/s eta 0:00:03
#      ------                                   1.6/10.6 MB 4.9 MB/s eta 0:00:02
#      -------                                  1.9/10.6 MB 4.7 MB/s eta 0:00:02
#      ---------                                2.5/10.6 MB 5.4 MB/s eta 0:00:02
#      ---------                                2.6/10.6 MB 5.4 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB 1.3 MB/s eta 0:00:06
#                                               0.1/7.6 MB 1.1 MB/s eta 0:00:07
#      -                                        0.2/7.6 MB 1.6 MB/s eta 0:00:05
#      -                                        0.4/7.6 MB 1.9 MB/s eta 0:00:04
#      --                                       0.5/7.6 MB 1.9 MB/s eta 0:00:04
#      ----                                     0.8/7.6 MB 2.7 MB/s eta 0:00:03
#      -----                                    1.1/7.6 MB 3.4 MB/s eta 0:00:02
#      -------                                  1.4/7.6 MB 3.9 MB/s eta 0:00:02
#      -------                                  1.4/7.6 MB 3.9 MB/s eta 0:00:02
#      -------                                  1.5/7.6 MB 3.4 MB/s eta 0:00:02
#      -------                                  1.5/7.6 MB 3.4 MB/s eta 0:00:02
# ...

# %%
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("GlobalLandTemperaturesByCity.csv")
data.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
data.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %%
data.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count        8.235082e+06                   8.235082e+06
# mean         1.672743e+01                   1.028575e+00
# std          1.035344e+01                   1.129733e+00
# min         -4.270400e+01                   3.400000e-02
# 25%          1.029900e+01                   3.370000e-01
# 50%          1.883100e+01                   5.910000e-01
# 75%          2.521000e+01                   1.349000e+00
# max          3.965100e+01                   1.539600e+01

# %%
data.shape
# Out:
# (8599212, 7)

# %%
data.isna().sum()
# Out:
# dt                                    0
# AverageTemperature               364130
# AverageTemperatureUncertainty    364130
# City                                  0
# Country                               0
# Latitude                              0
# Longitude                             0
# dtype: int64

# %%
data_prepared=data.dropna(axis=0,how="any")

# %%
data_prepared.shape
# Out:
# (8235082, 7)

# %%
data_prepared.isna().sum()
# Out:
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# City                             0
# Country                          0
# Latitude                         0
# Longitude                        0
# dtype: int64

# %%
data_prepared.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 5  1744-04-01               5.788                          3.624  Århus
# 6  1744-05-01              10.644                          1.283  Århus
# 7  1744-06-01              14.051                          1.347  Århus
# 8  1744-07-01              16.082                          1.396  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 5  Denmark   57.05N    10.33E
# 6  Denmark   57.05N    10.33E
# 7  Denmark   57.05N    10.33E
# 8  Denmark   57.05N    10.33E

# %%
data_prepared[["Country","City"]]
# Out:
#              Country    City
# 0            Denmark   Århus
# 5            Denmark   Århus
# 6            Denmark   Århus
# 7            Denmark   Århus
# 8            Denmark   Århus
# ...              ...     ...
# 8599206  Netherlands  Zwolle
# 8599207  Netherlands  Zwolle
# 8599208  Netherlands  Zwolle
# 8599209  Netherlands  Zwolle
# 8599210  Netherlands  Zwolle
#
# [8235082 rows x 2 columns]

# %%
data_prepared["Country"].value_counts()
# Out:
# Country
# India               960548
# China               819132
# United States       661524
# Brazil              451645
# Russia              448663
#                      ...
# Burundi               1675
# Eritrea               1669
# Djibouti              1658
# Oman                  1652
# Papua New Guinea      1580
# Name: count, Length: 159, dtype: int64

# %%
data_prepared[data_prepared["Country"]=="Turkey"]
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3239     1743-11-01              10.013                          2.291
# 3244     1744-04-01              13.685                          2.162
# 3245     1744-05-01              15.021                          1.824
# 3246     1744-06-01              19.663                          1.701
# 3247     1744-07-01              22.314                          1.648
# ...             ...                 ...                            ...
# 8585429  2013-04-01              11.876                          0.293
# 8585430  2013-05-01              17.662                          0.196
# 8585431  2013-06-01              19.818                          0.344
# 8585432  2013-07-01              21.343                          0.288
# 8585433  2013-08-01              22.225                          0.454
#
#               City Country Latitude Longitude
# 3239         Çorlu  Turkey   40.99N    27.69E
# ...

# %%
data_prepared[(data_prepared["Country"]=="Turkey")  | (data_prepared["Country"]=="Brazil") ]
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3239     1743-11-01              10.013                          2.291
# 3244     1744-04-01              13.685                          2.162
# 3245     1744-05-01              15.021                          1.824
# 3246     1744-06-01              19.663                          1.701
# 3247     1744-07-01              22.314                          1.648
# ...             ...                 ...                            ...
# 8585429  2013-04-01              11.876                          0.293
# 8585430  2013-05-01              17.662                          0.196
# 8585431  2013-06-01              19.818                          0.344
# 8585432  2013-07-01              21.343                          0.288
# 8585433  2013-08-01              22.225                          0.454
#
#               City Country Latitude Longitude
# 3239         Çorlu  Turkey   40.99N    27.69E
# ...

# %%
 data_prepared[(data_prepared["AverageTemperature"]>20)]
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 164      1757-07-01              20.179                          7.554
# 1088     1834-07-01              20.273                          1.791
# 1233     1846-08-01              20.193                          1.604
# 3008     1994-07-01              20.052                          0.216
# 3045     1997-08-01              20.883                          0.292
# ...             ...                 ...                            ...
# 8596449  1783-07-01              20.375                          2.354
# 8597158  1842-08-01              20.142                          1.215
# 8598981  1994-07-01              21.061                          0.231
# 8599018  1997-08-01              20.617                          0.245
# 8599125  2006-07-01              21.941                          0.246
#
#            City      Country Latitude Longitude
# 164       Århus      Denmark   57.05N    10.33E
# ...

# %%
data_prepared[data_prepared["Country"].isin(["Salvador","Brazil","United States"])]
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 47555    1820-01-01               2.101                          3.217
# 47556    1820-02-01               6.926                          2.853
# 47557    1820-03-01              10.767                          2.395
# 47558    1820-04-01              17.989                          2.202
# 47559    1820-05-01              21.809                          2.036
# ...             ...                 ...                            ...
# 8439242  2013-05-01              15.544                          0.281
# 8439243  2013-06-01              20.892                          0.273
# 8439244  2013-07-01              24.722                          0.279
# 8439245  2013-08-01              21.001                          0.323
# 8439246  2013-09-01              17.408                          1.048
#
#             City        Country Latitude Longitude
# 47555    Abilene  United States   32.95N   100.53W
# ...

# %%
data_prepared[data_prepared["Country"].isin(["Turkey","Brazil","United States"])]["Country"].value_counts()
# Out:
# Country
# United States    661524
# Brazil           451645
# Turkey           147086
# Name: count, dtype: int64

# %%
data_selected=data_prepared[data_prepared["Country"].isin(["Turkey","Brazil","United States"])]["Country"].value_counts()

# %%
data_selected.head()
# Out:
# Country
# United States    661524
# Brazil           451645
# Turkey           147086
# Name: count, dtype: int64

# %%
data_selected = data_prepared[data_prepared["Country"].isin(["Turkey", "Brazil", "United States"])]

# %%
print(data_selected.head())
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 3239  1743-11-01              10.013                          2.291  Çorlu
# 3244  1744-04-01              13.685                          2.162  Çorlu
# 3245  1744-05-01              15.021                          1.824  Çorlu
# 3246  1744-06-01              19.663                          1.701  Çorlu
# 3247  1744-07-01              22.314                          1.648  Çorlu
#
#      Country Latitude Longitude
# 3239  Turkey   40.99N    27.69E
# 3244  Turkey   40.99N    27.69E
# 3245  Turkey   40.99N    27.69E
# 3246  Turkey   40.99N    27.69E
# 3247  Turkey   40.99N    27.69E

# %%
data_selected.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 3239  1743-11-01              10.013                          2.291  Çorlu
# 3244  1744-04-01              13.685                          2.162  Çorlu
# 3245  1744-05-01              15.021                          1.824  Çorlu
# 3246  1744-06-01              19.663                          1.701  Çorlu
# 3247  1744-07-01              22.314                          1.648  Çorlu
#
#      Country Latitude Longitude
# 3239  Turkey   40.99N    27.69E
# 3244  Turkey   40.99N    27.69E
# 3245  Turkey   40.99N    27.69E
# 3246  Turkey   40.99N    27.69E
# 3247  Turkey   40.99N    27.69E

# %%
data_selected.groupby("Country").agg({
    "AverageTemperature": ["min", "mean", "max"],
    "AverageTemperatureUncertainty": ["min", "mean", "max"]
})
# Out:
#               AverageTemperature                     \
#                              min       mean     max
# Country
# Brazil                     9.591  21.902763  30.495
# Turkey                   -15.353  12.951888  32.885
# United States            -25.163  13.949335  34.379
#
#               AverageTemperatureUncertainty
#                                         min      mean     max
# Country
# Brazil                                0.040  0.869764   5.277
# Turkey                                0.056  1.275864   9.237
# United States                         0.040  1.089550  10.519

# %%
data_selected.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 3239  1743-11-01              10.013                          2.291  Çorlu
# 3244  1744-04-01              13.685                          2.162  Çorlu
# 3245  1744-05-01              15.021                          1.824  Çorlu
# 3246  1744-06-01              19.663                          1.701  Çorlu
# 3247  1744-07-01              22.314                          1.648  Çorlu
#
#      Country Latitude Longitude
# 3239  Turkey   40.99N    27.69E
# 3244  Turkey   40.99N    27.69E
# 3245  Turkey   40.99N    27.69E
# 3246  Turkey   40.99N    27.69E
# 3247  Turkey   40.99N    27.69E

# %%
data_selected[data_selected["Country"]=="Turkey"]
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3239     1743-11-01              10.013                          2.291
# 3244     1744-04-01              13.685                          2.162
# 3245     1744-05-01              15.021                          1.824
# 3246     1744-06-01              19.663                          1.701
# 3247     1744-07-01              22.314                          1.648
# ...             ...                 ...                            ...
# 8585429  2013-04-01              11.876                          0.293
# 8585430  2013-05-01              17.662                          0.196
# 8585431  2013-06-01              19.818                          0.344
# 8585432  2013-07-01              21.343                          0.288
# 8585433  2013-08-01              22.225                          0.454
#
#               City Country Latitude Longitude
# 3239         Çorlu  Turkey   40.99N    27.69E
# ...

# %%
data_selected[data_selected["Country"]=="Turkey"]["AverageTemperature"]
# Out:
# 3239       10.013
# 3244       13.685
# 3245       15.021
# 3246       19.663
# 3247       22.314
#             ...
# 8585429    11.876
# 8585430    17.662
# 8585431    19.818
# 8585432    21.343
# 8585433    22.225
# Name: AverageTemperature, Length: 147086, dtype: float64

# %%
tr_avg_temps=data_selected[data_selected["Country"]=="Turkey"]["AverageTemperature"]
br_avg_temps=data_selected[data_selected["Country"]=="Brazil"]["AverageTemperature"]
usa_avg_temps=data_selected[data_selected["Country"]=="United States"]["AverageTemperature"]

# %%
sns.distplot(tr_avg_temps)
sns.distplot(br_avg_temps)
sns.distplot(usa_avg_temps)
# Out:
# C:\Users\ugurb\AppData\Local\Temp\ipykernel_3472\2250528222.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tr_avg_temps)
# C:\Users\ugurb\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
